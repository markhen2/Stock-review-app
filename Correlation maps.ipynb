# %%
import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (15, 8)

end = datetime.datetime.now()
start = end - datetime.timedelta(days=365*5)

WTI=str('crud.l')
ticker_list = ['FANG', 'MPC', 'EOG', 'PSX', 'VLO.VI', 'TTE', 'BP', 'CL=F','BZ=F','BZM24.NYM', 'GAS-EUR','WTID.MI']
            

def get_prices(tickers, start):
    prices = pd.DataFrame()
    for ticker in tickers:
        data = yf.download(ticker, start=start, end=end)
        if 'Adj Close' in data:
            prices[ticker] = data['Adj Close']
        else:
            print(f"Warning: 'Adj Close' not found for {ticker}. Skipping.")
    return prices

prices_df = get_prices(ticker_list, start)
print(prices_df.shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# (1256, 12)

# %%
from matplotlib import colormaps
change_df = prices_df.pct_change()
change_df.dropna(inplace=True)
sns.heatmap(change_df.corr() ,annot=True);
# Out:
# /var/folders/mk/fn7b709x3dz4m442ngj1_xf00000gn/T/ipykernel_45974/945541940.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   change_df = prices_df.pct_change()

# %%
import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (15, 8)

end = datetime.datetime.now()
start = end - datetime.timedelta(days=365*5)

WTI=str('crud.l')
ticker_list = ['MPC', 'EOG', 'PSX', 'VLO.VI', 'TTE', 'BP','cop' ,'CL=F','BZ=F','BZM24.NYM','WTID.MI']

def get_prices(tickers, start):
    prices = pd.DataFrame()
    for ticker in tickers:
        data = yf.download(ticker, start=start, end=end)
        if 'Adj Close' in data:
            prices[ticker] = data['Adj Close']
        else:
            print(f"Warning: 'Adj Close' not found for {ticker}. Skipping.")
    return prices

prices_df = get_prices(ticker_list, start)

# Define a dictionary mapping old ticker names to new display names
ticker_name_mapping = {
    
    'MPC': 'MPC',
    'EOG': 'EOG ',
    'PSX': 'Phillips66',
    'VLO.VI': 'Valero',
    'TTE': 'TotalEnergies',
    'BP': 'BP ',
    'cop': 'Connoco',
    'CL=F': 'Crude Oil ',
    'BZ=F': 'Brent Crude',
    'BZM24.NYM': 'Brent Jun 24 ',
    'WTID.MI': 'WTI Crude'
}

# Rename the columns of the DataFrame
prices_df.rename(columns=ticker_name_mapping, inplace=True)          

print(prices_df.shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# (1256, 11)

# %%
from matplotlib import colormaps
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate percentage change
change_df = prices_df.pct_change()

# Drop missing values
change_df.dropna(inplace=True)

# Check if DataFrame is empty
if change_df.empty:
    print("DataFrame is empty")
else:
    # Create heatmap
    sns.heatmap(change_df.corr(), annot=True)

    # Display the plot
    plt.show()
# Out:
# /var/folders/mk/fn7b709x3dz4m442ngj1_xf00000gn/T/ipykernel_45974/2051382568.py:6: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   change_df = prices_df.pct_change()

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api.catalyst.zoho.com")
payload = json.dumps({
  "data": {
    "Date": "2020-07-21",
    "Distances": 0.04184428
  }
})
headers = {
  'X-QUICKML-ENDPOINT-KEY': '77dc64697d4900e861dad8829ab7d17f47d39dddd96834806edb865ab610f18f646ef3569a586b516ce5775da4c642bd',
  'Authorization': 'Zoho-oauthtoken 1000.cf53f26119aedeab8f6a524bd0bd413c.dff9b3ca667daf362701edaf1f82944a',
  'CATALYST-ORG': '814842417',
  'Environment': 'Development',
  'Content-Type': 'application/json',
  'Cookie': '5f04ea12a2=1f548b1cc8a9c7a556d24d960fdeccf9; _zcsr_tmp=d81f2c83-b50d-449a-896a-27be58648c85; ziahubcsr=d81f2c83-b50d-449a-896a-27be58648c85'
}
conn.request("POST", "/quickml/v1/project/17937000000033012/endpoints/predict", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"code":"INVALID_OAUTHTOKEN","message":"INVALID_OAUTHTOKEN","details":{}}
